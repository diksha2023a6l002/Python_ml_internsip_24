# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import os
# %matplotlib inline

# %%
auto=pd.read_csv("Automobile_data.csv")
auto.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
plt.plot(auto["make"],auto["fuel"])
plt.show()

# %%
plt.bar(auto["make"],auto["fuel-type"])
plt.show()

# %%
brandVSfuel=auto.groupby(["make", "fuel-type"]).size().unstack(fill_value=0)
brandVSfuel
# Out:
# fuel-type      diesel  gas
# make
# alfa-romero         0    3
# audi                0    7
# bmw                 0    8
# chevrolet           0    3
# dodge               0    9
# honda               0   13
# isuzu               0    4
# jaguar              0    3
# mazda               2   15
# mercedes-benz       4    4
# mercury             0    1
# mitsubishi          0   13
# nissan              1   17
# peugot              5    6
# plymouth            0    7
# porsche             0    5
# renault             0    2
# saab                0    6
# subaru              0   12
# toyota              3   29
# volkswagen          4    8
# volvo               1   10

# %%
brandVSfuel.plot(kind="bar", stacked=True)
plt.show()

# %%
#Catagorize the cars on the basis of their price... 1.Budget  2.MidRange  3.HighRange  4.Premium
#Then show the availability of these cars in every brand.

#Creating function
'''def cat_price():
    if price<=10000:
        print("Budget Car")
    elif price<=20000:
        print("Mid Range Car")
    elif price<=30000:
        ("High Range Car")
    elif price>30000:
        print("Premium Car")'''

#cat_price=auto.groupby(["price"]).size().unstack(fill_value=0)
#cat_price

plt.plot(auto["price"])
plt.show()

# %%
plt.figure(figsize=(15,6))

sns.lineplot(data=auto["wheel-base"], linewidth=1, label="Wheel-Base")
sns.lineplot(data=auto["engine-size"], linewidth=1, label="Engine-Size")

plt.title("Wheel Base VS Engine Size", color='y')
plt.xlabel("Engine Size", color='g', fontsize=15.5)
plt.ylabel("Wheel Base", color='r', fontsize=15.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(20,8))
sns.set(rc={"axes.facecolor":"#FFFF0F", "axes.grid":False, "xtick.labelsize":10, "ytick.labelsize":10})

plt.title("Wheel Base VS Engine Size")
plt.ylabel("Wheel Base")
plt.xlabel("Engine Size")
plt.xticks(rotation=45)
sns.lineplot(x=auto["engine-size"],y=auto["wheel-base"].index.values,color='r')
plt.show()

# %%
2024-08-06 18:34:06.720 [info] Extension host with pid 16416 started
2024-08-06 18:34:06.837 [info] ExtensionService#_doActivateExtension vscode.ipynb, startup: false, activationEvent: 'onNotebookSerializer:jupyter-notebook'
2024-08-06 18:34:06.909 [info] ExtensionService#_doActivateExtension vscode.configuration-editing, startup: false, activationEvent: 'onLanguage:jsonc'
2024-08-06 18:34:06.939 [info] ExtensionService#_doActivateExtension vscode.json-language-features, startup: false, activationEvent: 'onLanguage:jsonc'
2024-08-06 18:34:07.146 [info] ExtensionService#_doActivateExtension vscode.typescript-language-features, startup: false, activationEvent: 'onLanguage:jsonc'
2024-08-06 18:34:07.700 [info] ExtensionService#_doActivateExtension vscode.emmet, startup: false, activationEvent: 'onLanguage'
2024-08-06 18:34:09.809 [info] ExtensionService#_doActivateExtension vscode.git-base, startup: true, activationEvent: '*', root cause: vscode.git
2024-08-06 18:34:10.773 [info] ExtensionService#_doActivateExtension vscode.git, startup: true, activationEvent: '*'
2024-08-06 18:34:11.160 [info] ExtensionService#_doActivateExtension vscode.github, startup: true, activationEvent: '*'
2024-08-06 18:34:11.734 [info] Eager extensions activated
2024-08-06 18:34:11.755 [info] ExtensionService#_doActivateExtension vscode.debug-auto-launch, startup: false, activationEvent: 'onStartupFinished'
2024-08-06 18:34:11.774 [info] ExtensionService#_doActivateExtension vscode.merge-conflict, startup: false, activationEvent: 'onStartupFinished'
2024-08-06 18:34:11.899 [info] ExtensionService#_doActivateExtension formulahendry.code-runner, startup: false, activationEvent: 'onStartupFinished'
2024-08-06 18:34:16.990 [info] ExtensionService#_doActivateExtension VisualStudioExptTeam.intellicode-api-usage-examples, startup: false, activationEvent: 'onLanguage:python'
2024-08-06 18:34:17.511 [info] ExtensionService#_doActivateExtension VisualStudioExptTeam.vscodeintellicode, startup: false, activationEvent: 'onLanguage:python'
